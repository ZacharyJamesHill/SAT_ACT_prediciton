# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# What determines the changes in participation rates for the ACT and SAT

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
sat_17 = pd.read_csv('../data/sat_2017.csv')
act_17 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
display(act_17.head(10))
display(sat_17.head(10))
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2
# ...

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# The first column of the ACT is an indexing column. The second column is a list of states and at the top a spot for the national scores. The third column contains percentage participation in the test. The fourth column contains the average  scores. The fifth column contains the average math scores. The sixth column contains the average reading scores. The seventh column contains the average science scores. The eighth column contains the average composite scores.
#
# The first column of the SAT is an indexing column. The second column is a list of states and at the top a spot for the national scores. The third column contains percentage participation in the test. The fourth column contains the average evidence-based reading and writing  scores. The fifth column contains the average math scores. The sixth column contains the average total scores.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# The data does look complete there are no values marked as None.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %%
sat_errors = []
for i in range(0,51):
    if sat_17.iloc[i,2] < 200 or sat_17.iloc[i,2] > 800: 
        sat_errors.append([i,2])

    
    if sat_17.iloc[i,3] < 200 or sat_17.iloc[i,3] > 800:
        sat_errors.append([i,3])
    
    if sat_17.iloc[i,4] < 400 or sat_17.iloc[i,4] > 1600:
        sat_errors.append(c[i,4])

print(sat_errors)

act_errors = []
for i in range(0,51):
    
    if act_17.iloc[i,2] < 1 or act_17.iloc[i,2] > 75: 
        act_errors.append([i,2])

    
    if act_17.iloc[i,3] < 1 or act_17.iloc[i,3] > 60:
        act_errors.append([i,3])
    
    if act_17.iloc[i,4] < 1 or act_17.iloc[i,4] > 40:
        act_errors.append([i,4])
    
    
    if act_17.iloc[i,5] < 1 or act_17.iloc[i,5] > 36:
        act_errors.append([i,5])

print(act_errors)
# Out:
# [[20, 3]]
# []

# %%
print(act_17)
print(sat_17)

# print((act_17.iloc(4, act_17.columns.get_loc('Math'))))

# print(act_17.reindex([act_17['Math']]))

print(act_17.iloc[51,6])
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# The ACT has a minimum score of 1 on each section and the composite. It has maximum of 75 in english, 60 in math, 40 in science, and 36 in the composite. The SAT has a minimum of 200 on each section, a minimum of 400 on the total, a maximum of 800 on each section, and a maximum of 1600 on the total.
#
# At cell sat_17[20, 3] there was a score lower than the minimum
#
# act composite 51 is 20.2x sat 20 math is under the minimum

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
sat_17.iloc[20, sat_17.columns.get_loc('Math')] = sat_17.iloc[20, sat_17.columns.get_loc('Total')] - sat_17.iloc[20, sat_17.columns.get_loc('Evidence-Based Reading and Writing')]

print(sat_17.iloc[20,3])



act_17.iloc[51, act_17.columns.get_loc('Composite')] = np.float64(20.2)

print(act_17.iloc[51,6])
# Out:
# 524
# 20.2

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
sat_data_types = []
act_data_types = []


for i in range(0, 51):
    
    sat_data_types.append(type(sat_17.iloc[i,1]))
    
    sat_data_types.append(type(sat_17.iloc[i,2]))
    
    sat_data_types.append(type(sat_17.iloc[i,3]))
    
    sat_data_types.append(type(sat_17.iloc[i,4]))
    
for i in range(0, 52):
    
    act_data_types.append(type(act_17.iloc[i,1]))
    
    act_data_types.append(type(act_17.iloc[i,2]))
    
    act_data_types.append(type(act_17.iloc[i,3]))
   
    act_data_types.append(type(act_17.iloc[i,4]))
   
    act_data_types.append(type(act_17.iloc[i,5]))
    
    act_data_types.append(type(act_17.iloc[i,6]))


# print(sat_data_types)
# print(act_data_types)

for i in sat_data_types:
    
    if i != type(np.int64(1)):
        print(i)

for i in act_data_types:

     if i != type(np.float64(1.0)):
            print(i)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
sat_17.head(5)
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# The composite column in act_17 appears to be mistyped as string, and the final entry in the column is 20.2x

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
def percentage_to_float(percentage):
    
    deconstructed = [letter for letter in percentage if letter != '%']
    
    reconstructed = ''
    for i in deconstructed:
        reconstructed += i
    
    reconstructed = float(reconstructed) / 100
    
    return reconstructed







sat_17.loc[:, 'Participation'] = sat_17.loc[:, 'Participation'].apply(percentage_to_float)

display(sat_17.head())


act_17.loc[:, 'Participation'] = act_17.loc[:, 'Participation'].apply(percentage_to_float)

display(act_17.head())
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.05                                 593   572   1165
# 1      Alaska           0.38                                 547   533   1080
# 2     Arizona           0.30                                 563   553   1116
# 3    Arkansas           0.03                                 614   594   1208
# 4  California           0.53                                 531   524   1055
#       State  Participation  English  Math  Reading  Science Composite
# 0  National           0.60     20.3  20.7     21.4     21.0      21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5      19.4

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
for i in range(0, 51):
    
    sat_data_types.append(type(sat_17.iloc[i,1]))
    
    sat_data_types.append(type(sat_17.iloc[i,2]))
    
    sat_data_types.append(type(sat_17.iloc[i,3]))
    
    sat_data_types.append(type(sat_17.iloc[i,4]))
    
for i in range(0, 52):
    
    act_data_types.append(type(act_17.iloc[i,1]))
    
    act_data_types.append(type(act_17.iloc[i,2]))
    
    act_data_types.append(type(act_17.iloc[i,3]))
   
    act_data_types.append(type(act_17.iloc[i,4]))
   
    act_data_types.append(type(act_17.iloc[i,5]))
    
    act_data_types.append(type(act_17.iloc[i,6]))


# print(sat_data_types)
# print(act_data_types)

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
sat_17.columns = sat_17.columns.str.lower()
sat_17.columns = sat_17.columns.str.replace(' ', '_')
sat_17.columns = sat_17.columns + ('_sat_17')
sat_17.rename(columns = {'state_sat_17':'state'}, inplace = True)
display(sat_17.head())

act_17.columns = act_17.columns.str.lower()
act_17.columns = act_17.columns.str.replace(' ', '_')
act_17.columns = act_17.columns + ('_act_17')
act_17.rename(columns = {'state_act_17':'state'}, inplace = True)

display(act_17.head())
# Out:
#         state  participation_sat_17  \
# 0     Alabama                  0.05
# 1      Alaska                  0.38
# 2     Arizona                  0.30
# 3    Arkansas                  0.03
# 4  California                  0.53
#
#    evidence-based_reading_and_writing_sat_17  math_sat_17  total_sat_17
# 0                                        593          572          1165
# 1                                        547          533          1080
# 2                                        563          553          1116
# 3                                        614          594          1208
# 4                                        531          524          1055
#       state  participation_act_17  english_act_17  math_act_17  \
# 0  National                  0.60            20.3         20.7
# 1   Alabama                  1.00            18.9         18.4
# 2    Alaska                  0.65            18.7         19.8
# ...

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state_sat_17  |object|SAT|The name of the state that provided this row's data|
# |participation_sat_17 |float|SAT|The percent participation in the test across the state|
# |evidence-based_reading_and_writing_sat_17|int|SAT|Average reading and writing section score|
# |math_sat_17|int|SAT|Average math section score|
# |total_sat_17|int|SAT|Average total score|
# |state_act_17|object|ACT|The name of the state that provided this row's data|
# |participation_act_17|float|ACT|The percent participation in the test across the state|
# |english_act_17|float|ACT|Average english section score|
# |math_act_17|float|ACT|Average math section score|
# |reading_act_17|float|ACT|Average reading section score|
# |science_act_17|float|ACT|Average science section score|
# |composite_act_17|float|ACT|Average composite score|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# print(act_17.tail())
# print(sat_17.tail())

# print(act_17.loc[:, 'state_act_17'])

# print(sat_17.loc[:, 'state_sat_17'])

act_17.drop(0, inplace = True)

display(act_17.head())
# Out:
#         state  participation_act_17  english_act_17  math_act_17  \
# 1     Alabama                  1.00            18.9         18.4
# 2      Alaska                  0.65            18.7         19.8
# 3     Arizona                  0.62            18.6         19.8
# 4    Arkansas                  1.00            18.9         19.0
# 5  California                  0.31            22.5         22.7
#
#    reading_act_17  science_act_17 composite_act_17
# 1            19.7            19.4             19.2
# 2            20.4            19.9             19.8
# 3            20.1            19.8             19.7
# 4            19.7            19.5             19.4
# 5            23.1            22.2             22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
print(act_17.shape)
print(sat_17.shape)

act_sat_17 = act_17.merge(sat_17, on = 'state', how = 'outer')

act_sat_17.head()
# Out:
# (51, 7)
# (51, 5)
#         state  participation_act_17  english_act_17  math_act_17  \
# 0     Alabama                  1.00            18.9         18.4
# 1      Alaska                  0.65            18.7         19.8
# 2     Arizona                  0.62            18.6         19.8
# 3    Arkansas                  1.00            18.9         19.0
# 4  California                  0.31            22.5         22.7
#
#    reading_act_17  science_act_17 composite_act_17  participation_sat_17  \
# 0            19.7            19.4             19.2                  0.05
# 1            20.4            19.9             19.8                  0.38
# 2            20.1            19.8             19.7                  0.30
# 3            19.7            19.5             19.4                  0.03
# 4            23.1            22.2             22.8                  0.53
#
#    evidence-based_reading_and_writing_sat_17  math_sat_17  total_sat_17
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
act_sat_17.to_csv('./combined_2017.csv', index = False)

# %%
act_sat_17.describe()
# Out:
#        participation_act_17  english_act_17  math_act_17  reading_act_17  \
# count             51.000000       51.000000    51.000000       51.000000
# mean               0.652549       20.931373    21.182353       22.013725
# std                0.321408        2.353677     1.981989        2.067271
# min                0.080000       16.300000    18.000000       18.100000
# 25%                0.310000       19.000000    19.400000       20.450000
# 50%                0.690000       20.700000    20.900000       21.800000
# 75%                1.000000       23.300000    23.100000       24.150000
# max                1.000000       25.500000    25.300000       26.000000
#
#        science_act_17  participation_sat_17  \
# count       51.000000             51.000000
# mean        21.041176              0.398039
# std          3.182463              0.352766
# min          2.300000              0.020000
# 25%         19.900000              0.040000
# ...

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
#reading data sets into dataframes
act_18 = pd.read_csv('../data/act_2018.csv')
sat_18 = pd.read_csv('../data/sat_2018.csv')

display(act_18.head())
display(sat_18.head())
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
#Cleaning column names

sat_18.columns = sat_18.columns.str.lower()
sat_18.columns = sat_18.columns.str.replace(' ', '_')
sat_18.columns = sat_18.columns + ('_sat_18')
sat_18.rename(columns = {'state_sat_18':'state'}, inplace = True)
display(sat_18.head())

act_18.columns = act_18.columns.str.lower()
act_18.columns = act_18.columns.str.replace(' ', '_')
act_18.columns = act_18.columns + ('_act_18')
act_18.rename(columns = {'state_act_18':'state'}, inplace = True)
display(act_18.head())
# Out:
#         state participation_sat_18  evidence-based_reading_and_writing_sat_18  \
# 0     Alabama                   6%                                        595
# 1      Alaska                  43%                                        562
# 2     Arizona                  29%                                        577
# 3    Arkansas                   5%                                        592
# 4  California                  60%                                        540
#
#    math_sat_18  total_sat_18
# 0          571          1166
# 1          544          1106
# 2          572          1149
# 3          576          1169
# 4          536          1076
#         state participation_act_18  composite_act_18
# 0     Alabama                 100%              19.1
# 1      Alaska                  33%              20.8
# 2     Arizona                  66%              19.2
# 3    Arkansas                 100%              19.4
# ...

# %%
#Cleaning Participation columns
sat_18.loc[:, 'participation_sat_18'] = sat_18.loc[:, 'participation_sat_18'].apply(percentage_to_float)

display(sat_18)


act_18.loc[:, 'participation_act_18'] = act_18.loc[:, 'participation_act_18'].apply(percentage_to_float)

display(act_18)
# Out:
#                    state  participation_sat_18  \
# 0                Alabama                  0.06
# 1                 Alaska                  0.43
# 2                Arizona                  0.29
# 3               Arkansas                  0.05
# 4             California                  0.60
# 5               Colorado                  1.00
# 6            Connecticut                  1.00
# 7               Delaware                  1.00
# 8   District of Columbia                  0.92
# 9                Florida                  0.56
# 10               Georgia                  0.70
# 11                Hawaii                  0.56
# 12                 Idaho                  1.00
# 13              Illinois                  0.99
# 14               Indiana                  0.63
# 15                  Iowa                  0.03
# 16                Kansas                  0.04
# 17              Kentucky                  0.04
# 18             Louisiana                  0.04
# ...

# %%
#checking data set shape
print(sat_18.shape)

print(act_18.shape)

#too many rows so looking for extras


    
# print([value for value in act_18['state_act_18'] if value not in sat_18['state_sat_18']])
      
    
print(act_18['state'])

print(sat_18['state'])      
    
    
print(act_18['state'].value_counts())

print(sat_18['state'].value_counts())   

# act has an extra Maine row [19]
# Out:
# (51, 5)
# (52, 3)
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                   Maine
# 21                Maryland
# 22           Massachusetts
# 23                Michigan
# 24               Minnesota
# 25             Mississippi
# 26                Missouri
# 27                 Montana
# 28                Nebraska
# 29                  Nevada
# 30           New Hampshire
# 31              New Jersey
# 32              New Mexico
# ...

# %%
#removing act row 19
act_18 = act_18.drop(19)
act_18.shape
# Out:
# (51, 3)

# %%
#district of columbia capitalized differently  act needs changingfixing
# print(act_18['state'])
# print(sat_18['state'])

act_18.iloc[8,0] = 'District of Columbia'

act_18.iloc[8,0]
# Out:
# 'District of Columbia'

# %%
#checking value types
display(act_18.describe())
sat_18.describe()
# Out:
#        participation_act_18  composite_act_18
# count             51.000000         51.000000
# mean               0.617255         21.496078
# std                0.340371          2.111583
# min                0.070000         17.700000
# 25%                0.285000         19.950000
# 50%                0.660000         21.300000
# 75%                1.000000         23.650000
# max                1.000000         25.600000
#        participation_sat_18  evidence-based_reading_and_writing_sat_18  \
# count             51.000000                                  51.000000
# mean               0.457451                                 563.686275
# std                0.373143                                  47.502627
# min                0.020000                                 480.000000
# 25%                0.045000                                 534.500000
# 50%                0.520000                                 552.000000
# ...

# %%
# checking types
# for element in act_sat_17['composite_act_17']:
#     print(element)
#     print(type(element))

act_sat_17.loc[:, 'composite_act_17'] = act_sat_17.loc[:, 'composite_act_17'].apply(float)

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
act_sat_18 = act_18.merge(sat_18, on = 'state', how = 'outer')

# display(act_sat_18.head())

# display(act_sat_18.head())
# display(act_sat_18)

act_sat_17_18 = act_sat_17.merge(act_sat_18, on = 'state', how = 'outer')

display(act_sat_17_18.head())

act_sat_17_18.shape


act_sat_17_18.reset_index()

print(act_sat_17_18.columns)
# Out:
#         state  participation_act_17  english_act_17  math_act_17  \
# 0     Alabama                  1.00            18.9         18.4
# 1      Alaska                  0.65            18.7         19.8
# 2     Arizona                  0.62            18.6         19.8
# 3    Arkansas                  1.00            18.9         19.0
# 4  California                  0.31            22.5         22.7
#
#    reading_act_17  science_act_17  composite_act_17  participation_sat_17  \
# 0            19.7            19.4              19.2                  0.05
# 1            20.4            19.9              19.8                  0.38
# 2            20.1            19.8              19.7                  0.30
# 3            19.7            19.5              19.4                  0.03
# 4            23.1            22.2              22.8                  0.53
#
#    evidence-based_reading_and_writing_sat_17  math_sat_17  total_sat_17  \
# ...

# %%
act_sat_18['participation_act_18']
# Out:
# 0     1.00
# 1     0.33
# 2     0.66
# 3     1.00
# 4     0.27
# 5     0.30
# 6     0.26
# 7     0.17
# 8     0.32
# 9     0.66
# 10    0.53
# 11    0.89
# 12    0.36
# 13    0.43
# 14    0.32
# 15    0.68
# 16    0.71
# 17    1.00
# 18    1.00
# 19    0.07
# 20    0.31
# 21    0.25
# 22    0.22
# 23    0.99
# 24    1.00
# 25    1.00
# 26    1.00
# 27    1.00
# 28    1.00
# 29    0.16
# 30    0.31
# 31    0.67
# 32    0.27
# 33    1.00
# 34    0.98
# 35    1.00
# 36    1.00
# 37    0.42
# 38    0.20
# 39    0.15
# 40    1.00
# 41    0.77
# 42    1.00
# 43    0.45
# 44    1.00
# 45    0.24
# 46    0.24
# 47    0.24
# 48    0.65
# 49    1.00
# 50    1.00
# Name: participation_act_18, dtype: float64

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
act_sat_17_18.describe()
# Out:
#        participation_act_17  english_act_17  math_act_17  reading_act_17  \
# count             51.000000       51.000000    51.000000       51.000000
# mean               0.652549       20.931373    21.182353       22.013725
# std                0.321408        2.353677     1.981989        2.067271
# min                0.080000       16.300000    18.000000       18.100000
# 25%                0.310000       19.000000    19.400000       20.450000
# 50%                0.690000       20.700000    20.900000       21.800000
# 75%                1.000000       23.300000    23.100000       24.150000
# max                1.000000       25.500000    25.300000       26.000000
#
#        science_act_17  composite_act_17  participation_sat_17  \
# count       51.000000         51.000000             51.000000
# mean        21.041176         21.519608              0.398039
# std          3.182463          2.020695              0.352766
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
def standard_deviation(data_set):
  
    mean = sum(data_set)
    
    
    mean = float(mean)
    
    mean /= len(data_set)
    
    std = 0
    
    for n in data_set:
        std += (float(n) - mean)**2
    
    std /= len(data_set)
    
    std = std**.5
    
    return std

standard_deviation(act_sat_17_18['english_act_17'])
# Out:
# 2.3304876369363363

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
sd = {col:standard_deviation(act_sat_17_18[col]) for col in act_sat_17_18 if col != 'state'}
      
                                                                                   

print(sd)
# Out:
# {'participation_act_17': 0.3182417575123181, 'english_act_17': 2.3304876369363363, 'math_act_17': 1.9624620273436781, 'reading_act_17': 2.0469029314842646, 'science_act_17': 3.151107895464408, 'composite_act_17': 2.000786081581989, 'participation_sat_17': 0.3492907076664507, 'evidence-based_reading_and_writing_sat_17': 45.21697020437866, 'math_sat_17': 46.65713364485503, 'total_sat_17': 91.58351056778743, 'participation_act_18': 0.33701735820410317, 'composite_act_18': 2.090779082141178, 'participation_sat_18': 0.3694661922353942, 'evidence-based_reading_and_writing_sat_18': 47.03460978357609, 'math_sat_18': 47.30194550378352, 'total_sat_18': 93.22742384464433}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#finding minimum and max participation 
 
min_sat_part_17 = act_sat_17_18['participation_sat_17'] == min(act_sat_17_18['participation_sat_17'])
print('sat 2017 states with minimum participation')
print(act_sat_17_18['state'][min_sat_part_17])

min_sat_part_18 = act_sat_17_18['participation_sat_18'] == min(act_sat_17_18['participation_sat_18'])
print('sat 2018 states with minimum participation')
print(act_sat_17_18['state'][min_sat_part_18])

min_act_part_17 = act_sat_17_18['participation_act_17'] == min(act_sat_17_18['participation_act_17'])
print('act 2017 states with minimum participation')
print(act_sat_17_18['state'][min_act_part_17])

min_act_part_18 = act_sat_17_18['participation_act_18'] == min(act_sat_17_18['participation_act_18'])
print('act 2018 states with minimum participation')
print(act_sat_17_18['state'][min_act_part_18])

 
max_sat_part_17 = act_sat_17_18['participation_sat_17'] == max(act_sat_17_18['participation_sat_17'])
print('sat 2017 states with maximum participation')
print(act_sat_17_18['state'][max_sat_part_17])

max_sat_part_18 = act_sat_17_18['participation_sat_18'] == max(act_sat_17_18['participation_sat_18'])
print('sat 2018 states with maximum participation')
print(act_sat_17_18['state'][max_sat_part_18])

max_act_part_17 = act_sat_17_18['participation_act_17'] == max(act_sat_17_18['participation_act_17'])
print('act 2017 states with maximum participation')
print(act_sat_17_18['state'][max_act_part_17])

max_act_part_18 = act_sat_17_18['participation_act_18'] == max(act_sat_17_18['participation_act_18'])
print('act 2018 states with maximum participation')
print(act_sat_17_18['state'][max_act_part_18])
# Out:
# sat 2017 states with minimum participation
# 15            Iowa
# 24     Mississippi
# 34    North Dakota
# Name: state, dtype: object
# sat 2018 states with minimum participation
# 34    North Dakota
# Name: state, dtype: object
# act 2017 states with minimum participation
# 19    Maine
# Name: state, dtype: object
# act 2018 states with minimum participation
# 19    Maine
# Name: state, dtype: object
# sat 2017 states with maximum participation
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 22                Michigan
# Name: state, dtype: object
# sat 2018 states with maximum participation
# 5        Colorado
# 6     Connecticut
# 7        Delaware
# 12          Idaho
# 22       Michigan
# Name: state, dtype: object
# act 2017 states with maximum participation
# 0            Alabama
# 3           Arkansas
# 5           Colorado
# 17          Kentucky
# 18         Louisiana
# 23         Minnesota
# 24       Mississippi
# ...

# %% [markdown]
# # Particpation Max and Min

# %%
min_sat_mean_17 = act_sat_17_18['total_sat_17'] == min(act_sat_17_18['total_sat_17'])
print(act_sat_17_18['state'][min_sat_mean_17])

min_sat_mean_18 = act_sat_17_18['total_sat_18'] == min(act_sat_17_18['total_sat_18'])
print(act_sat_17_18['state'][min_sat_mean_18])

min_act_mean_17 = act_sat_17_18['composite_act_17'] == min(act_sat_17_18['composite_act_17'])
print(act_sat_17_18['state'][min_act_mean_17])

min_act_mean_18 = act_sat_17_18['composite_act_18'] == min(act_sat_17_18['composite_act_18'])
print(act_sat_17_18['state'][min_act_mean_18])

 
max_sat_mean_17 = act_sat_17_18['total_sat_17'] == max(act_sat_17_18['total_sat_17'])
print(act_sat_17_18['state'][max_sat_mean_17])

max_sat_mean_18 = act_sat_17_18['total_sat_18'] == max(act_sat_17_18['total_sat_18'])
print(act_sat_17_18['state'][max_sat_mean_18])

max_act_mean_17 = act_sat_17_18['composite_act_17'] == max(act_sat_17_18['composite_act_17'])
print(act_sat_17_18['state'][max_act_mean_17])

max_act_mean_18 = act_sat_17_18['composite_act_18'] == max(act_sat_17_18['composite_act_18'])
print(act_sat_17_18['state'][max_act_mean_18])
# Out:
# 8    District of Columbia
# Name: state, dtype: object
# 8    District of Columbia
# Name: state, dtype: object
# 28    Nevada
# Name: state, dtype: object
# 28    Nevada
# Name: state, dtype: object
# 23    Minnesota
# Name: state, dtype: object
# 23    Minnesota
# Name: state, dtype: object
# 29    New Hampshire
# Name: state, dtype: object
# 6    Connecticut
# Name: state, dtype: object

# %% [markdown]
# # Mean Final Score Max and Min

# %%
#do any of the 100% participation states have a change in participation between years
max_sat_part_17 = act_sat_17_18['participation_sat_17'] == max(act_sat_17_18['participation_sat_17'])

act_sat_17_18['state'][max_sat_part_17]

max_sat_part_18 = act_sat_17_18['participation_sat_18'] == max(act_sat_17_18['participation_sat_18'])

act_sat_17_18['state'][max_sat_part_18]

max_act_part_17 = act_sat_17_18['participation_act_17'] == max(act_sat_17_18['participation_act_17'])

act_sat_17_18['state'][max_act_part_17]

max_act_part_18 = act_sat_17_18['participation_act_18'] == max(act_sat_17_18['participation_act_18'])

act_sat_17_18['state'][max_act_part_18]

# from https://www.geeksforgeeks.org/python-union-two-lists/

def Union(lst1, lst2): 
    final_list = list(set(lst1) | set(lst2)) 
    return final_list 

states_with_100_participation = Union(Union(act_sat_17_18['state'][max_sat_part_18], act_sat_17_18['state'][max_sat_part_17]), Union(act_sat_17_18['state'][max_act_part_17]
, act_sat_17_18['state'][max_act_part_18]))


print(states_with_100_participation)


states_with_particpation_change_act = [state for state in states_with_100_participation if (act_sat_17_18.loc[act_sat_17_18['state'] == state, 'participation_act_17'] != act_sat_17_18.loc[act_sat_17_18['state'] == state, 'participation_act_18']).bool()]

print(states_with_particpation_change_act)

states_with_particpation_change_sat = [state for state in states_with_100_participation if (act_sat_17_18.loc[act_sat_17_18['state'] == state, 'participation_sat_17'] != act_sat_17_18.loc[act_sat_17_18['state'] == state, 'participation_sat_18']).bool()]

print(states_with_particpation_change_sat)
# Out:
# ['Missouri', 'Utah', 'Kentucky', 'Wyoming', 'Montana', 'Idaho', 'Arkansas', 'South Carolina', 'District of Columbia', 'Connecticut', 'Minnesota', 'Nevada', 'Nebraska', 'Mississippi', 'North Carolina', 'Colorado', 'Alabama', 'Oklahoma', 'Ohio', 'Wisconsin', 'Louisiana', 'Tennessee', 'Delaware', 'Michigan']
# ['Idaho', 'Connecticut', 'Minnesota', 'Nebraska', 'Colorado', 'Ohio', 'Delaware', 'Michigan']
# ['Missouri', 'Utah', 'Idaho', 'Arkansas', 'South Carolina', 'District of Columbia', 'Minnesota', 'Nevada', 'Mississippi', 'North Carolina', 'Colorado', 'Alabama', 'Oklahoma', 'Ohio', 'Tennessee']

# %% [markdown]
# # Change in Participation Rates Among States With 100% Particpation

# %%
#Do any states show have >50% participation on both tests either year



[state for state in act_sat_17_18['state'] if (state in (act_sat_17_18['participation_act_17'] > .50) and  state in (act_sat_17_18['participation_sat_17'] > .50)) or (state in (act_sat_17_18['participation_act_18'] > .50) and state in (act_sat_17_18['participation_sat_18'] > .50))]

#no
# Out:
# []

# %%
display(act_sat_17_18)
# Out:
#                    state  participation_act_17  english_act_17  math_act_17  \
# 0                Alabama                  1.00            18.9         18.4
# 1                 Alaska                  0.65            18.7         19.8
# 2                Arizona                  0.62            18.6         19.8
# 3               Arkansas                  1.00            18.9         19.0
# 4             California                  0.31            22.5         22.7
# 5               Colorado                  1.00            20.1         20.3
# 6            Connecticut                  0.31            25.5         24.6
# 7               Delaware                  0.18            24.1         23.4
# 8   District of Columbia                  0.32            24.4         23.5
# 9                Florida                  0.73            19.0         19.4
# 10               Georgia                  0.55            21.0         20.9
# ...

# %% [markdown]
# # Biggest Change in Participation Between Years (added)

# %%
#finding states with biggest participation changes
#ACT

def act_dif(state):
    return((act_sat_17_18[act_sat_17_18['state'] == state]['participation_act_18'] - act_sat_17_18[act_sat_17_18['state'] == state]['participation_act_17']))


differences_act = act_sat_17_18['state'].map(act_dif)

differences_act = [differences_act[i][i] for i in range(0,51)]

print(max(differences_act))
print(min(differences_act))
# print(differences_act)

#SAT

def sat_dif(state):
    return((act_sat_17_18[act_sat_17_18['state'] == state]['participation_sat_18'] - act_sat_17_18[act_sat_17_18['state'] == state]['participation_sat_17']))


differences_sat = act_sat_17_18['state'].map(sat_dif)

differences_sat = [differences_sat[i][i] for i in range(0,51)]

print(max(differences_sat))
print(min(differences_sat))
# print(differences_sat)



participation_changes = act_sat_17_18.drop(columns = [ 'participation_act_17', 'english_act_17', 'math_act_17',
       'reading_act_17', 'science_act_17', 'composite_act_17',
       'participation_sat_17', 'evidence-based_reading_and_writing_sat_17',
       'math_sat_17', 'total_sat_17', 'participation_act_18',
       'composite_act_18', 'participation_sat_18',
       'evidence-based_reading_and_writing_sat_18', 'math_sat_18',
       'total_sat_18'])

participation_changes['sat_difs'] = differences_sat
participation_changes['act_difs'] = differences_act

display(participation_changes.sort_values(by = ['sat_difs']))

display(participation_changes.sort_values(by = ['act_difs']))
# Out:
# 0.25
# -0.7
# 0.9
# -0.2699999999999999
#                    state  sat_difs  act_difs
# 9                Florida     -0.27     -0.07
# 8   District of Columbia     -0.08      0.00
# 28                Nevada     -0.03      0.00
# 2                Arizona     -0.01      0.04
# 17              Kentucky      0.00      0.00
# 16                Kansas      0.00     -0.02
# 49             Wisconsin      0.00      0.00
# 14               Indiana      0.00     -0.03
# 26               Montana      0.00      0.00
# 27              Nebraska      0.00      0.16
# 50               Wyoming      0.00      0.00
# 18             Louisiana      0.00      0.00
# 7               Delaware      0.00     -0.01
# 6            Connecticut      0.00     -0.05
# 34          North Dakota      0.00      0.00
# 41          South Dakota      0.00     -0.03
# 29         New Hampshire      0.00     -0.02
# 22              Michigan      0.00     -0.07
# 36              Oklahoma      0.01      0.00
# ...

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize = (12,12),)

plt.title('Correlations Between Test Scores')

sns.heatmap(act_sat_17_18.corr(), annot = True, cmap = 'coolwarm', square = True);

# %% [markdown]
# # Heatmap Interpretation
# The above plot presents the correlations between each test score, where positive correlations are red, and negative correlations are blue. The centerline is 100% correlated because it is measuring a score against itself.

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (15,10)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])
        # Set titles, labels, etc here for each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
subplot_histograms(act_sat_17_18,
                   ['participation_act_17', 'participation_sat_17', 'participation_act_18', 'participation_sat_18'],
                   ['ACT 2017 Participation', 'SAT 2017 Participation', 'ACT 2018 Participation', 'SAT 2018 Participation'],
                   ['percent participation', 'percent participation', 'percent participation', 'percent participation',])

# %% [markdown]
# # Participation Histogram Interpretation
# The above histograms demonstrate how participation in each state is distributed.

# %%
subplot_histograms(act_sat_17_18,
                   ['math_act_17', 'math_sat_17', 'math_sat_18'],
                   ['ACT 2017 Math', 'SAT 2017 Math', 'SAT 2018 Math'],
                   ['math score', 'math score', 'math score'])

# %% [markdown]
# # Math Score Histogram Interpretation

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
act_sat_17_18.head()
# Out:
#         state  participation_act_17  english_act_17  math_act_17  \
# 0     Alabama                  1.00            18.9         18.4
# 1      Alaska                  0.65            18.7         19.8
# 2     Arizona                  0.62            18.6         19.8
# 3    Arkansas                  1.00            18.9         19.0
# 4  California                  0.31            22.5         22.7
#
#    reading_act_17  science_act_17  composite_act_17  participation_sat_17  \
# 0            19.7            19.4              19.2                  0.05
# 1            20.4            19.9              19.8                  0.38
# 2            20.1            19.8              19.7                  0.30
# 3            19.7            19.5              19.4                  0.03
# 4            23.1            22.2              22.8                  0.53
#
#    evidence-based_reading_and_writing_sat_17  math_sat_17  total_sat_17  \
# ...

# %%
def subplot_scatter(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) 
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (20,15)) 
    ax = ax.ravel() 
    for i, column in enumerate(list_of_columns):
        
        ax[i].scatter(dataframe[column[0]], dataframe[column[1]])
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])
        ax[i].set_ylabel(list_of_ylabels[i])
        

    
        
        
subplot_scatter(act_sat_17_18, [('math_sat_17','math_act_17'),
                                ('evidence-based_reading_and_writing_sat_17', 'reading_act_17'),
                                ('total_sat_17', 'composite_act_17'),
                                ('total_sat_17', 'total_sat_18'), 
                               ('composite_act_17','composite_act_18')],
                ['SAT Math vs. ACT Math 2017', 'SAT Reading vs. ACT Reading 2017', 'SAT Total vs. ACT Composite 2017',
                'SAT 2017 vs. SAT 2018 Totals', 'ACT 2017 vs. ACT 2018 Totals'], 
                ['SAT Score','SAT Score','SAT Score','SAT Score','ACT Score'],
                ['ACT Score','ACT Score','ACT Score','SAT Score','ACT Score'])

# %% [markdown]
# # Scatterplot Interpretation
# The above scatterplots can be used to see the relationship betweem test scores. The closer the points are to being in line the more highly correlated the two variables are.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
fig, ax = plt.subplots(figsize = (9,6))


for i, column in enumerate(act_sat_17_18.keys()):
    if column == 'state':
        pass
    else:
        plt.show(sns.boxplot(x = act_sat_17_18[column]))

# %% [markdown]
# #  Boxplot Interpretation
# The above boxplots are used to show the distribution of each statistic. The centerline is the median, the outer lines of the box are the first and last quartile, the ends of the through line are the maximum and the minimum, and the diamonds represent outliers

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#histogram of differences in participation rates between each year

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %%
subplot_histograms(participation_changes,['sat_difs','act_difs'],
                  ['Distibution of Change in SAT Participation 2017-2018','Distibution of Change in ACT Participation 2017-2018'],
                  ['change in fraction of participation','change in fraction of participation'])

# %% [markdown]
# # Additional Histogram Interpretation
# The above histograms show the distribution of the changes in participation rates in the ACT and SAT from 2017 to 2018.

# %% [markdown]
# ## Descriptive and Inferential Statistics (Bonus)

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
# Florida SAT, Alaska ACT, Nebraska ACT
# These states show the greatest change in participation rates excepting those states in which some test is mandatory

display(act_sat_17_18[act_sat_17_18['state'] == 'West Virginia'])

display(act_sat_17_18[act_sat_17_18['state'] == 'Alaska'])

display(act_sat_17_18[act_sat_17_18['state'] == 'Nebraska'])
# Out:
#             state  participation_act_17  english_act_17  math_act_17  \
# 48  West Virginia                  0.69            20.0         19.4
#
#     reading_act_17  science_act_17  composite_act_17  participation_sat_17  \
# 48            21.2            20.5              20.4                  0.14
#
#     evidence-based_reading_and_writing_sat_17  math_sat_17  total_sat_17  \
# 48                                        558          528          1086
#
#     participation_act_18  composite_act_18  participation_sat_18  \
# 48                  0.65              20.3                  0.28
#
#     evidence-based_reading_and_writing_sat_18  math_sat_18  total_sat_18
# 48                                        513          486           999
#     state  participation_act_17  english_act_17  math_act_17  reading_act_17  \
# 1  Alaska                  0.65            18.7         19.8            20.4
#
#    science_act_17  composite_act_17  participation_sat_17  \
# ...

# %%
econ_18 = pd.read_csv('../data/state_M2018_dl.csv')

econ_18.drop(inplace = True, columns = ['AREA','ST','OCC_GROUP','TOT_EMP','EMP_PRSE','LOC_Q','H_MEDIAN','H_PCT75','H_PCT90','A_PCT10','A_PCT25','A_MEDIAN','A_PCT75','A_PCT90','ANNUAL','HOURLY'])
econ_18.drop(inplace = True, columns = ['H_MEAN','A_MEAN','MEAN_PRSE','H_PCT10','H_PCT25'])


econ_17 = pd.read_csv('../data/state_M2017_dl.csv')

econ_17.drop(inplace = True, columns = ['AREA','ST','OCC_GROUP','TOT_EMP','EMP_PRSE','LOC_Q','H_MEDIAN','H_PCT75','H_PCT90','A_PCT10','A_PCT25','A_MEDIAN','A_PCT75','A_PCT90','ANNUAL','HOURLY'])
econ_17.drop(inplace = True, columns = ['H_MEAN','A_MEAN','MEAN_PRSE','H_PCT10','H_PCT25'])


econ_17['OCC_CODE'] = [code[-4:] for code in econ_17['OCC_CODE']]

econ_18['OCC_CODE'] = [code[-4:] for code in econ_18['OCC_CODE']]


al_jobs_18 = econ_18[(econ_18['STATE'] == 'Alaska') & (econ_18['OCC_CODE'] == '0000')]

al_jobs_17 = econ_17[(econ_17['STATE'] == 'Alaska') & (econ_17['OCC_CODE'] == '0000')]

al_jobs_18.drop(columns = ['STATE', 'OCC_CODE'], inplace = True)

al_jobs_17.drop(columns = ['STATE', 'OCC_CODE'], inplace = True)

al_job_change = al_jobs_18

temp = al_jobs_18['JOBS_1000'].map(float).reset_index() - al_jobs_17['JOBS_1000'].map(float).reset_index()

temp.drop(columns = 'index', inplace = True)



al_job_change['jobs_1000_dif'] = [temp.iloc[n][0] for n in range(len(temp))]

al_job_change = al_jobs_18.drop(columns = ['JOBS_1000'])



wv_jobs_18 = econ_18[(econ_18['STATE'] == 'West Virginia') & (econ_18['OCC_CODE'] == '0000')]

wv_jobs_17 = econ_17[(econ_17['STATE'] == 'West Virginia') & (econ_17['OCC_CODE'] == '0000')]

wv_jobs_17.drop(columns = ['STATE', 'OCC_CODE'], inplace = True)

wv_jobs_18.drop(columns = ['STATE', 'OCC_CODE'], inplace = True)

wv_job_change = wv_jobs_18

temp = wv_jobs_18['JOBS_1000'].map(float).reset_index() - wv_jobs_17['JOBS_1000'].map(float).reset_index()

temp.drop(columns = 'index', inplace = True)



wv_job_change['jobs_1000_dif'] = [temp.iloc[n][0] for n in range(len(temp))]

wv_job_change = wv_jobs_18.drop(columns = ['JOBS_1000'])


ne_jobs_18 = econ_18[(econ_18['STATE'] == 'Nebraska') & (econ_18['OCC_CODE'] == '0000')]

ne_jobs_17 = econ_17[(econ_17['STATE'] == 'Nebraska') & (econ_17['OCC_CODE'] == '0000')]


ne_jobs_17.drop(columns = ['STATE', 'OCC_CODE'], inplace = True)

ne_jobs_18.drop(columns = ['STATE', 'OCC_CODE'], inplace = True)


ne_job_change = ne_jobs_18

temp = ne_jobs_18['JOBS_1000'].map(float).reset_index() - ne_jobs_17['JOBS_1000'].map(float).reset_index()

temp.drop(columns = 'index', inplace = True)



ne_job_change['jobs_1000_dif'] = [temp.iloc[n][0] for n in range(len(temp))]

ne_job_change = ne_jobs_18.drop(columns = ['JOBS_1000'])

# print('AL')
# display(al_job_change)
# print('WV')
# display(wv_job_change)
# print('NE')
# display(ne_job_change)
# display(econ_18)
# display(econ_17)
# econ_17['OCC_CODE']
# al_job_change.reset_index()

print(al_job_change.iloc[[1,2,3,4,5,7,8,9,10,17]].sum(axis = 0))

print(al_job_change.iloc[[11,12,13,14,15,16,18,19,20,21,22]].sum(axis = 0))



print(wv_job_change.iloc[[1,2,3,4,5,7,8,9,10,17]].sum(axis = 0))

print(wv_job_change.iloc[[11,12,13,14,15,16,18,19,20,21,22]].sum(axis = 0))


print(ne_job_change.iloc[[1,2,3,4,5,7,8,9,10,17]].sum(axis = 0))

print(ne_job_change.iloc[[11,12,13,14,15,16,18,19,20,21,22]].sum(axis = 0))

# print(al_job_change)
# Out:
#                                               OCC_TITLE JOBS_1000
# 738                                     All Occupations  1000.000
# 739                              Management Occupations    62.738
# 771       Business and Financial Operations Occupations    40.600
# 797               Computer and Mathematical Occupations    16.748
# 812            Architecture and Engineering Occupations    25.159
# 840      Life, Physical, and Social Science Occupations    18.962
# 865            Community and Social Service Occupations    22.699
# 883                                   Legal Occupations     6.899
# 891        Education, Training, and Library Occupations    69.173
# 924   Arts, Design, Entertainment, Sports, and Media...    10.867
# 948   Healthcare Practitioners and Technical Occupat...    56.307
# 998                      Healthcare Support Occupations    25.050
# 1014                     Protective Service Occupations    25.070
# ...

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# # Conclusions and Recomendations
# In states that are losing jobs that require college degrees participation rates in the SAT and ACT are increasing, and visa versa. If the SAT and/or ACT want to increase participation they should target states where there are large econimic shifts, because the potential change in participation in those states is much larger than in other states.
